# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#with-plt.subplots" data-toc-modified-id="with-plt.subplots-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>with <code>plt.subplots</code></a></span><ul class="toc-item"><li><span><a href="#4x1-grid" data-toc-modified-id="4x1-grid-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>4x1 grid</a></span></li><li><span><a href="#4x2-grid" data-toc-modified-id="4x2-grid-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>4x2 grid</a></span></li><li><span><a href="#Multiple-plots-with-a-common-grid" data-toc-modified-id="Multiple-plots-with-a-common-grid-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Multiple plots with a common grid</a></span></li></ul></li><li><span><a href="#With-plt.subplot2grid" data-toc-modified-id="With-plt.subplot2grid-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>With <code>plt.subplot2grid</code></a></span><ul class="toc-item"><li><span><a href="#4x1-grid" data-toc-modified-id="4x1-grid-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>4x1 grid</a></span></li><li><span><a href="#4x2-grid" data-toc-modified-id="4x2-grid-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>4x2 grid</a></span></li><li><span><a href="#various-sizes" data-toc-modified-id="various-sizes-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>various sizes</a></span></li></ul></li><li><span><a href="#With-gridspec" data-toc-modified-id="With-gridspec-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>With <code>gridspec</code></a></span><ul class="toc-item"><li><span><a href="#4x1-grid" data-toc-modified-id="4x1-grid-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>4x1 grid</a></span></li><li><span><a href="#4x2-grid" data-toc-modified-id="4x2-grid-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>4x2 grid</a></span></li><li><span><a href="#various-sizes" data-toc-modified-id="various-sizes-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>various sizes</a></span></li></ul></li><li><span><a href="#Other-useful-subplot-adjustments" data-toc-modified-id="Other-useful-subplot-adjustments-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Other useful subplot adjustments</a></span><ul class="toc-item"><li><span><a href="#Space-between-plots:" data-toc-modified-id="Space-between-plots:-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Space between plots:</a></span></li><li><span><a href="#Remove-the-tick-labels:" data-toc-modified-id="Remove-the-tick-labels:-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Remove the tick labels:</a></span></li><li><span><a href="#Share-axis:" data-toc-modified-id="Share-axis:-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Share axis:</a></span><ul class="toc-item"><li><span><a href="#with-plt.subplots" data-toc-modified-id="with-plt.subplots-4.3.1"><span class="toc-item-num">4.3.1&nbsp;&nbsp;</span>with <code>plt.subplots</code></a></span></li><li><span><a href="#with-plt.subplot2grid" data-toc-modified-id="with-plt.subplot2grid-4.3.2"><span class="toc-item-num">4.3.2&nbsp;&nbsp;</span>with <code>plt.subplot2grid</code></a></span></li></ul></li><li><span><a href="#Change-side-of-the-lables:" data-toc-modified-id="Change-side-of-the-lables:-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Change side of the lables:</a></span></li></ul></li></ul></div>

# %% [markdown]
# # Multiple plots with `matplotlib`:
#
# some references: https://matplotlib.org/tutorials/intermediate/gridspec.html

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# Create some random data:

# %%
x=np.random.uniform(0,10,10000)
y=np.random.uniform(0,10,10000)

# %% [markdown]
# ## with `plt.subplots`
#
# Note that subplots only works well for plots with equal sizes but plotting very different sizes of plots with it is not a straightforward task.
#
# It creates a grid of plots all at once such as they can be easily called inside a loop.

# %% [markdown]
# ### 4x1 grid

# %%
fig, axes = plt.subplots(4,1, figsize=(8,8))
co=['r','k','b','g']
for i in range(4):
    ax=axes[i]
    plt.subplot(ax)
    plt.plot(x,y,'.',c=co[i])

# %% [markdown]
# ### 4x2 grid

# %%
fig, axes = plt.subplots(4,2, figsize=(8,8))
co=np.array([['r','k','b','g'],['y','gray','c','m']]).transpose()
for i in range(4):
    for j in range(2):
        ax=axes[i,j]
        plt.subplot(ax)
        plt.plot(x,y,'.',c=co[i,j])

# %% [markdown]
# ### Multiple plots with a common grid

# %%
fig,axis= plt.subplots(1,4,figsize = (8,4))
co=np.array(['r','k','b','g'])


for i in range(4):
    ax=axis[i]
    plt.subplot(ax)
    plt.plot(x+i*10,y,'.',c=co[i])
    plt.setp(ax.get_yticklabels(), visible=False)

plt.show()

# %%
fig,axis= plt.subplots(1,4,sharey=True,figsize = (8,4))
co=np.array(['r','k','b','g'])

plt.subplots_adjust(wspace=0., hspace=0.)

t=[0]
for i in range(4):
    ax=axis[i]
    plt.subplot(ax)
    plt.plot(x+i*10,y,'.',c=co[i])
    plt.setp(ax.get_yticklabels(), visible=False)
    plt.setp(ax.get_xticklabels(), visible=False) 
    plt.setp(ax.get_yticklabels(), visible=False)
    t.append((i+1)*10)
    plt.xlim(x.min()+i*10,x.max()+i*10)

fig.add_subplot(111, frameon=False,sharey=ax)

plt.xticks(t,t)
plt.xlabel("common X")
plt.ylabel("common Y")
plt.xlim(0,40)
plt.show()

# %% [markdown]
# ## With `plt.subplot2grid`
#
# As long as I understand it is more robust for creating a grid of plots with different sizes. But I it seems to create each plot per time, and so in case of repeated plots inside a loop, I need to repeat it.  **can this be improved?**

# %% [markdown]
# ### 4x1 grid

# %%
fig= plt.subplots(figsize = (8,8))
co=['r','k','b','g']
for i in range(4):
    ax=plt.subplot2grid((4,1),(i,0),colspan=1,rowspan=1)
    plt.plot(x,y,'.',c=co[i])

# %% [markdown]
# ### 4x2 grid

# %%
fig= plt.subplots(figsize = (12,12))
co=np.array([['r','k','b','g'],['y','gray','c','m']]).transpose()
for i in range(4):
    for j in range(2):
        ax=plt.subplot2grid((4,4),(i,j),colspan=1,rowspan=1)
        plt.plot(x,y,'.',c=co[i,j])

# %% [markdown]
# ### various sizes

# %% [markdown]
# But this is still restricted to multiples of the grid size definition.

# %%
axis[0]

# %%
fig= plt.subplots(figsize = (12,12))
co=np.array(['r','k','b','g','y','gray','c','m'])

axis=[]
axis.append(plt.subplot2grid((4,4),(0,0),colspan=4,rowspan=1))
axis.append(plt.subplot2grid((4,4),(1,0),colspan=3,rowspan=1))
axis.append(plt.subplot2grid((4,4),(1,3),colspan=1,rowspan=3))
axis.append(plt.subplot2grid((4,4),(2,0),colspan=1,rowspan=1))
axis.append(plt.subplot2grid((4,4),(2,1),colspan=2,rowspan=1))


for i in range(5):
    plt.subplot(axis[i])
    plt.plot(x,y,'.',c=co[i])

# %% [markdown]
# ## With `gridspec`

# %%
import matplotlib.gridspec as gridspec

# %%
gs = gridspec.GridSpec(4, 1)

# %%
gs
# Out:
# GridSpec(4, 1)

# %% [markdown]
# ### 4x1 grid

# %%
fig= plt.subplots(figsize = (8,8))
co=['r','k','b','g']
gs = gridspec.GridSpec(4, 1)
for i in range(4):
    ax =plt.subplot(gs[i])
    plt.plot(x,y,'.',c=co[i])

# %% [markdown]
# ### 4x2 grid

# %%
fig= plt.subplots(figsize = (8,8))
gs = gridspec.GridSpec(4, 2)
co=np.array([['r','k','b','g'],['y','gray','c','m']]).transpose()
for i in range(4):
    for j in range(2):
        ax = plt.subplot(gs[i,j])
        plt.plot(x,y,'.',c=co[i,j])

# %% [markdown]
# ### various sizes

# %%
fig= plt.subplots(figsize = (8,8))

gs = gridspec.GridSpec(4, 4)
co=np.array(['r','k','b','g','y','gray','c','m'])

axis=[]
axis.append(gs[0,:])
axis.append(gs[1,:-1])
axis.append(gs[1:,-1])
axis.append(gs[2,0])
axis.append(gs[2,1:3])


for i in range(5):
    ax = plt.subplot(axis[i])
    plt.plot(x,y,'.',c=co[i])

# %% [markdown]
# ## Other useful subplot adjustments
#
# ### Space between plots:
# To set the space between each plot in the grid (or remove it completely)

# %%
fig= plt.subplots(figsize = (4,4))
co=np.array([['r','k','b','g'],['y','gray','c','m']]).transpose()
for i in range(4):
    for j in range(2):
        ax=plt.subplot2grid((4,4),(i,j),colspan=1,rowspan=1)
        plt.plot(x,y,'.',c=co[i,j])

#add:
plt.subplots_adjust(wspace=0., hspace=0.)

# %% [markdown]
# ### Remove the tick labels:

# %%
fig= plt.subplots(figsize = (4,4))
co=np.array([['r','k','b','g'],['y','gray','c','m']]).transpose()
for i in range(4):
    for j in range(2):
        ax=plt.subplot2grid((4,4),(i,j),colspan=1,rowspan=1)
        plt.plot(x,y,'.',c=co[i,j])
#add
        plt.setp(ax.get_xticklabels(), visible=False) 
        plt.setp(ax.get_yticklabels(), visible=False)

# %% [markdown]
# ### Share axis:
#
# To share the same y or x axis in all plots:

# %% [markdown]
# #### with `plt.subplots`

# %% [markdown]
# A single `plt.ylim` sets the range in the `y` axis for all plots

# %%
fig, axes = plt.subplots(4,2, sharex=True, sharey=True, figsize=(4,4))
co=np.array([['r','k','b','g'],['y','gray','c','m']]).transpose()
for i in range(4):
    for j in range(2):
        ax=axes[i,j]
        plt.subplot(ax)
        plt.plot(x,y,'.',c=co[i,j])
plt.ylim(-3,15)
# Out:
# (-3, 15)

# %% [markdown]
# #### with `plt.subplot2grid`
#
# Only works if one of the axis if defined before:

# %%
fig= plt.subplots(figsize = (4,4))

ax0=plt.subplot2grid((4,2),(0,0),colspan=1,rowspan=1)
co=np.array([['r','k','b','g'],['y','gray','c','m']]).transpose()
for i in range(4):
    for j in range(2):
        ax=plt.subplot2grid((4,4),(i,j),colspan=1,rowspan=1,sharex=ax1,sharey=ax1)
        plt.plot(x,y,'.',c=co[i,j])
plt.ylim(-5,15)
# Out:
# (-5, 15)
